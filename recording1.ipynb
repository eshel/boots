# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('recording1.txt')

# %%
df = df.set_index(pd.to_datetime(df.t,unit='us'))
base = pd.to_datetime([0])[0]

# %%
fig = plt.figure(figsize=(18,10))
plt.subplot(3,1,1)
df.ax.plot()
plt.subplot(3,1,2)
df.ay.plot()
plt.subplot(3,1,3)
df.az.plot()

# %%
fig = plt.figure(figsize=(18,10))
(df.ax**2 + df.ay**2 + df.az**2).plot()

# %%
fig = plt.figure(figsize=(18,10))
(df.ax**2 + df.ay**2 + df.az**2).between_time(df.ax.index.min() + pd.datetools.Second()*8 ,df.ax.index.min() + pd.datetools.Second()*13).plot()
